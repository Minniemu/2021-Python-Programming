# %%
monoplyMap = [200, -200, 10000, -600, -2000, -3000, 0, 1000, 3000, -400]
monoplyStr = ["中發票+200元", "闖紅燈-200元", "中樂透+10000元", "紅線停車-600元", "繳汽車稅-2000元", "繳房屋稅-3000元", "停止一次", "得到股息+1000元", "工作得到獎金+3000元", "繳停車費-400元"]

class Monopoly:
    def __init__(self, property, steps, name):
        self.property = property
        self.steps = steps
        self.name = name
        self.go = True
        #self.position = 0
        #print("Property = ",property)
        #print("Steps = ",steps)
        #print("Name = ",name)
    
    def step(self,s):
        print("{0} move {1} steps".format(self.name,s))
        self.steps += s
            
            
        if self.steps > 9:
            print("繞行一周,得到特別獎金5000元")
            self.property += 5000
            self.steps = self.steps%9 - 1
        if self.steps == 6:
            self.go = False
        self.result()
        
    def result(self):
        self.property += monoplyMap[self.steps]
        print(monoplyStr[self.steps])
        print("=========={}==========".format(self.name))
        print("money : ",str(self.property))
        print("position : ",str(self.steps))
        print("\n")
    
    def stop(self):
        print("=========={}==========".format(self.name))
        print("money : ",str(self.property))
        print("position : ",str(self.steps))
        print("\n")

# %%
import random

n = input("Please input numbers of players = ")
n = int(n)
objs = [Monopoly(10000,0,'Player ' + str(i+1)) for i in range(n)]


count = 0    
while True:
    num = input("(0 for exit)")
    if num == '0':
        break
    obj_num = count%n
    #print("==========Player{}==========".format(obj_num+1))
    if objs[obj_num].go == False:
        print("{}本回合禁止移動".format(objs[obj_num].name))
        objs[obj_num].go = True
        objs[obj_num].stop()
    else:
        rand = random.randint(1,6)
        objs[obj_num].step(rand)
    
    count += 1
money = {}
winner = []
for i in range(n):
    m = objs[i].property
    n = objs[i].name
    money[n] = m
#print(money)
#find winner
all_values = money.values()
max_value = max(all_values)
#print("max_values = ",max_value)
for key,value in money.items():
    if value == max_value:
        winner.append(key)
listToStr = ' '.join([str(elem) for elem in winner])
print("{} win!".format(listToStr))
# Out:
# Please input numbers of players = 5
# (0 for exit)1
# Player 1 move 3 steps
# 紅線停車-600元
# ==========Player 1==========
# money :  9400
# position :  3
#
#
# (0 for exit)2
# Player 2 move 4 steps
# 繳汽車稅-2000元
# ==========Player 2==========
# money :  8000
# position :  4
#
#
# (0 for exit)6
# Player 3 move 1 steps
# 闖紅燈-200元
# ==========Player 3==========
# money :  9800
# position :  1
#
#
# (0 for exit)4
# Player 4 move 5 steps
# 繳房屋稅-3000元
# ==========Player 4==========
# money :  7000
# position :  5
#
#
# (0 for exit)9
# Player 5 move 6 steps
# 停止一次
# ==========Player 5==========
# money :  10000
# position :  6
#
#
# (0 for exit)1
# Player 1 move 1 steps
# 繳汽車稅-2000元
# ==========Player 1==========
# money :  7400
# position :  4
#
#
# (0 for exit)5
# Player 2 move 3 steps
# 得到股息+1000元
# ==========Player 2==========
# money :  9000
# position :  7
#
#
# (0 for exit)4
# Player 3 move 3 steps
# 繳汽車稅-2000元
# ==========Player 3==========
# money :  7800
# position :  4
#
#
# (0 for exit)8
# Player 4 move 4 steps
# 繳停車費-400元
# ==========Player 4==========
# money :  6600
# position :  9
#
#
# (0 for exit)3
# Player 5本回合禁止移動
# ==========Player 5==========
# money :  10000
# position :  6
#
#
# (0 for exit)0
# Player 5 win!

# %%
money = {1:2,3:4,2:4}
all_values = money.values()
max_value = max(all_values)
print(max_value)
for key,value in money.items():
    if value == max_value:
        print("key = ",key)
# Out:
# 4
# key =  3
# key =  2
